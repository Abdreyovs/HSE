# %%
import pandas as pd

# %%
data = pd.read_csv('../../data/telecom_churn.csv')

# %%
pd.read_csv?

# %%
data.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
# State                     3333 non-null object
# Account length            3333 non-null int64
# Area code                 3333 non-null int64
# International plan        3333 non-null object
# Voice mail plan           3333 non-null object
# Number vmail messages     3333 non-null int64
# Total day minutes         3333 non-null float64
# Total day calls           3333 non-null int64
# Total day charge          3333 non-null float64
# Total eve minutes         3333 non-null float64
# Total eve calls           3333 non-null int64
# Total eve charge          3333 non-null float64
# Total night minutes       3333 non-null float64
# Total night calls         3333 non-null int64
# Total night charge        3333 non-null float64
# Total intl minutes        3333 non-null float64
# Total intl calls          3333 non-null int64
# Total intl charge         3333 non-null float64
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
data['Churn'].value_counts()
# Out:
# False    2850
# True      483
# Name: Churn, dtype: int64

# %%
data[data['International plan'] == 'Yes']['Churn'].value_counts()
# Out:
# False    186
# True     137
# Name: Churn, dtype: int64

# %%
pd.crosstab(data['International plan'],
           data['Churn'])
# Out:
# Churn               False  True
# International plan
# No                   2664    346
# Yes                   186    137

# %%
data[(data['State'] == 'NY') & 
    (data['International plan'] == 'Yes')]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 985     NY              64        415                Yes              No
# 1044    NY              94        510                Yes              No
# 1309    NY             137        415                Yes              No
# 1752    NY             181        415                Yes              No
# 1872    NY              15        510                Yes              No
# 2401    NY             126        415                Yes              No
# 2987    NY             131        408                Yes              No
# 3086    NY              54        510                Yes              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 985                       0              346.8               55
# 1044                      0              243.2              109
# 1309                      0              174.0              123
# ...

# %%
data.shape
# Out:
# (3333, 20)

# %%
data['many_calls'] = data['Customer service calls'] > 4

# %%
data.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes    ...      Total eve charge  \
# 0             45.07              197.4    ...                 16.78
# ...

# %%
data['Total day calls'].describe()
# Out:
# count    3333.000000
# mean      100.435644
# std        20.069084
# min         0.000000
# 25%        87.000000
# 50%       101.000000
# 75%       114.000000
# max       165.000000
# Name: Total day calls, dtype: float64

# %%
# def many_talks(minutes):
#     return minutes > 100

# %%
data['many_talks'] = data['Total day calls']\
                    .apply(lambda x: x > 100)

# %%
data.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes    ...      Total night minutes  \
# 0             45.07              197.4    ...                    244.7
# ...

# %%
data['state_K'] = data['State'].apply(lambda x: 
                                      x[0] == 'K')

# %%
data[data['state_K']].head()
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 0      KS             128        415                 No             Yes
# 88     KY              74        415                 No             Yes
# 103    KY              95        408                 No              No
# 179    KS              70        408                 No              No
# 192    KY              80        408                 No              No
#
#      Number vmail messages  Total day minutes  Total day calls  \
# 0                       25              265.1              110
# 88                      35              154.1              104
# 103                      0              135.0               99
# 179                      0              232.1              122
# 192                      0              209.9               74
#
#      Total day charge  Total eve minutes   ...    Total night calls  \
# 0               45.07              197.4   ...                   91
# ...

# %%
for (plan, sub_df) in data.groupby('International plan'):
    print(plan)
    print(sub_df['Churn'].value_counts())
# Out:
# No
# False    2664
# True      346
# Name: Churn, dtype: int64
# Yes
# False    186
# True     137
# Name: Churn, dtype: int64

# %%
data.iloc[2, 3]
# Out:
# 'No'

# %%
data.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
values = [[17, 23], 
          [28, 45],
          [60,60]]

# %%
# %%time
df = pd.DataFrame(values, columns=['age', 'wage'], 
                 index=['John', 'Mary', 'Kate'])
# Out:
# CPU times: user 771 µs, sys: 32 µs, total: 803 µs
# Wall time: 781 µs

# %%
df
# Out:
#       age  wage
# John   17    23
# Mary   28    45
# Kate   60    60

# %%
df.iloc[2, 1] = pd.null
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-6745794c3e72> in <module>()
# ----> 1 df.iloc[2, 1] = pd.null
#
# AttributeError: module 'pandas' has no attribute 'null'

# %%
df.loc['Mary', 'wage']
# Out:
# 45

# %%
df.ix[:2, 'age']
# Out:
# John    17
# Mary    28
# Name: age, dtype: int64
